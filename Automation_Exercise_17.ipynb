# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
from selenium.webdriver.common.alert import Alert


def Launch_automation_exercise():
    url = 'https://automationexercise.com'
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.page_load_strategy = "eager"
    driver = webdriver.Chrome(options = options)
    driver.implicitly_wait(1)
    driver.get(url)
    print("Browser launched")
    return driver


def verify_home_page(driver):
    try:
        Home = driver.find_element(By.CSS_SELECTOR, 'a[href="/"]')
        print("Homepage Verified")
    except NoSuchElementException:
        print("Error")



def product_page(driver):
    try:
        product = driver.find_element(By.CSS_SELECTOR, 'a[href="/products"]' )
        product.click()
        print("product page clicked")
    except NoSuchElementException:
        print("Error")


def verify_product_page(driver):
    try:
        driver.find_element(By.XPATH, "//h2[normalize-space()='All Products']" )
        print("ALL products page verified")
    except NoSuchElementException:
        print("Error")

def safe_click(driver, element):
    driver.execute_script("arguments[0].scrollIntoView({block:'center'});", element)
    time.sleep(1)
    driver.execute_script("arguments[0].click();", element)


def add_cart(driver):
    try:
        for product_id in range (1,3):  # 1 and 2
            
            add_cart = driver.find_element(By.XPATH, f"//a[@data-product-id='{product_id}']")
            safe_click(driver, add_cart)
            print(f" Item {product_id} added")
            time.sleep(5)
            

            continue_shopping = driver.find_element(By.XPATH, '//button[normalize-space() = "Continue Shopping"]')
            safe_click(driver, continue_shopping)
            print("continue shopping clicked")
            time.sleep(2)

    except NoSuchElementException:
        print("Error")

def cart(driver):
    try:
        cart = driver.find_element(By.CSS_SELECTOR, 'a[href = "/view_cart"]')
        safe_click(driver, cart)

        print("cart clicked")
        time.sleep(5)
        
        driver.find_element(By.ID, "product-1")
        driver.find_element(By.ID, "product-2")
        print("Both products are added to Cart")
        

    except NoSuchElementException:
        print("Error")

def cart_delete(driver):
    try:
        cart_delete_1 = driver.find_element(By.XPATH, "//a[@class = 'cart_quantity_delete' and @data-product-id = '1']")
        cart_delete_1.click()
        print("item deleted 1")
        time.sleep(2)
        
        cart_delete_2 = driver.find_element(By.XPATH, "//a[@class = 'cart_quantity_delete' and @data-product-id = '2']")
        cart_delete_2.click()
        print("item deleted 2")
        time.sleep(2)
        
    except NoSuchElementException:
        print("Error")

def empty_cart(driver):
    try:
        driver.find_element(By.XPATH, "//b[normalize-space() = 'Cart is empty!']")
        print('cart is empty now')
        
    except NoSuchElementException:
        print("Error")
    

def main():
    
    driver = Launch_automation_exercise()
    time.sleep(5)

    try:
        verify_home_page(driver)
        time.sleep(5)
    
        product_page(driver)
        time.sleep(5)
    
        verify_product_page(driver)
        time.sleep(5)
    
        add_cart(driver)
        time.sleep(5)

        cart(driver)
        time.sleep(5)
        
        cart_delete(driver)
        time.sleep(5)
        
        empty_cart(driver)
        time.sleep(5)
        

    finally:
        driver.quit()
        print("Browser closed")

if __name__ == "__main__":
    main()
# Out:
# Browser launched
# Homepage Verified
# product page clicked
# ALL products page verified
#  Item 1 added
# continue shopping clicked
#  Item 2 added
# continue shopping clicked
# cart clicked
# Both products are added to Cart
# item deleted 1
# item deleted 2
# cart is empty now
# Browser closed
