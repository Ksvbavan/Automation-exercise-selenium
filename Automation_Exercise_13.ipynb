# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time
from selenium.webdriver.common.alert import Alert


def Launch_automation_exercise():
    url = 'https://automationexercise.com'
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.page_load_strategy = "eager"
    driver = webdriver.Chrome(options = options)
    driver.implicitly_wait(1)
    driver.get(url)
    print("Browser launched")
    return driver


def verify_home_page(driver):
    try:
        Home = driver.find_element(By.CSS_SELECTOR, 'a[href="/"]')
        print("Homepage Verified")
    except NoSuchElementException:
        print("Error")


def product_page(driver):
    try:
        product = driver.find_element(By.CSS_SELECTOR, 'a[href="/products"]' )
        product.click()
        print("product page clicked")
    except NoSuchElementException:
        print("Error")


def verify_product_page(driver):
    try:
        driver.find_element(By.XPATH, "//h2[normalize-space()='All Products']" )
        print("ALL products page verified")
    except NoSuchElementException:
        print("Error")


def product_details(driver):
    try:
        view_product = driver.find_element(By.CSS_SELECTOR,'a[href="/product_details/1"]' )
        view_product.click()
        print("view product page loaded")
        
    except NoSuchElementException:
        print("Error")

def add_quantity(driver):
    try:
        add_quantity = driver.find_element(By.ID, "quantity")
        add_quantity.clear()
        add_quantity.send_keys("4")
        print("quantity added")
        time.sleep(2)

        add_to_cart = driver.find_element(By.XPATH, "//button[normalize-space()='Add to cart']")
        add_to_cart.click()
        print("add to cart option clicked")
        time.sleep(2)
        
        continue_shopping = driver.find_element(By.XPATH, '//button[normalize-space() = "Continue Shopping"]')
        continue_shopping.click()
        print("continue shopping clicked")
        time.sleep(2)

    except NoSuchElementException:
        print("Error")


def cart(driver):
    try:
        cart = driver.find_element(By.CSS_SELECTOR, 'a[href = "/view_cart"]')
        cart.click()
        print("cart clicked")
        time.sleep(5)
        
        driver.find_element(By.ID, "product-1")
        print("product added to Cart")
        
    except NoSuchElementException:
        print("Error")

def verify_cart(driver):
    try:
        row = driver.find_element(By.ID, "product-1")
        quantity = row.find_element(By.CLASS_NAME, "cart_quantity").text

        print(f"  Quantity : {quantity}")


        print("Quantity verified for the product")

    except NoSuchElementException:
        print("Error")
        


def main():
    
    driver = Launch_automation_exercise()
    time.sleep(5)

    try:
        verify_home_page(driver)
        time.sleep(5)
    
        product_page(driver)
        time.sleep(5)
    
        verify_product_page(driver)
        time.sleep(5)
    
        product_details(driver)
        time.sleep(5)

        add_quantity(driver)
        time.sleep(5)
        
        cart(driver)
        time.sleep(5)
        
        verify_cart(driver)
        time.sleep(5)

    finally:
        driver.quit()
        print("Browser closed")

if __name__ == "__main__":
    main()
# Out:
# Browser launched
# Homepage Verified
# product page clicked
# ALL products page verified
# view product page loaded
# quantity added
# add to cart option clicked
# continue shopping clicked
# cart clicked
# product added to Cart
#   Quantity : 4
# Quantity verified for the product
# Browser closed
