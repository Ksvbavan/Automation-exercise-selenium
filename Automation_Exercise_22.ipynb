# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
import time

def Launch_automation_exercise():
    url = 'https://automationexercise.com'
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.page_load_strategy = "eager"
    driver = webdriver.Chrome(options = options)
    driver.implicitly_wait(1)
    driver.get(url)
    print("Browser launched")
    return driver


def verify_home_page(driver):
    try:
        Home = driver.find_element(By.CSS_SELECTOR, 'a[href="/"]')
        print("Homepage Verified")
    except NoSuchElementException:
        print("Error finding Homepage")

def safe_scroll(driver, element):
    driver.execute_script("arguments[0].scrollIntoView({block:'center'});", element)
    time.sleep(1)

def recommended_item(driver):
    try:
        scroll = driver.find_element(By.XPATH, "//h2[normalize-space() = 'recommended items']")
        safe_scroll(driver, scroll)
        print("recommended_item [topic verified]")
    
    except NoSuchElementException:
        print("Error finding Homepage")

def recommended_product(driver):
    try:
        recommended_product = driver.find_element(By.XPATH, "//a[@data-product-id='4' and contains(@class, 'add-to-cart')]")
        recommended_product.click()
        print("product added")
        time.sleep(2)

        continue_shopping = driver.find_element(By.XPATH, '//button[normalize-space() = "Continue Shopping"]')
        continue_shopping.click()
        print("continue shopping clicked")
        time.sleep(2)

    except NoSuchElementException:
        print("Error finding Homepage")

def safe_click(driver, element):
    driver.execute_script("arguments[0].scrollIntoView({block:'center'});", element)
    time.sleep(1)
    driver.execute_script("arguments[0].click();", element)

def cart(driver):
    try:
        cart = driver.find_element(By.CSS_SELECTOR, 'a[href = "/view_cart"]')
        safe_click(driver, cart)

        print("cart clicked")
        time.sleep(5)
        
        driver.find_element(By.ID, "product-4")
        print("product verified")
        

    except NoSuchElementException:
        print("Error")

def main():

    driver = Launch_automation_exercise()
    time.sleep(5)

    try:
        verify_home_page(driver)
        time.sleep(5)     
        
        recommended_item(driver)
        time.sleep(5)    

        recommended_product(driver)
        time.sleep(5)

        cart(driver)
        time.sleep(5)
        
    finally:
        
        driver.quit()
        print("Browser closed")

if __name__ == "__main__":
    main()
# Out:
# Browser launched
# Homepage Verified
# recommended_item [topic verified]
# product added
# continue shopping clicked
# cart clicked
# product verified
# Browser closed
